# %%
import torch
from torchvision import transforms
from PIL import Image
import numpy as np
from skimage import color
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image_path = 'test_images/2015.jpg'

# %%
image = Image.open(image_path)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x10E20C250>

# %%
image_data = np.array(image)
image_data.shape
# Out:
# (333, 500, 3)

# %%
plt.imshow(image_data)

# %%
lab_image = color.rgb2lab(image_data)

# %%
plt.imshow(lab_image)
lab_image.shape
# Out:
# (333, 500, 3)

# %%
lab_rgb = color.lab2rgb(lab_image)

# %%
plt.imshow(lab_rgb)

# %%
from torchvision import transforms
crop = transforms.RandomCrop([256, 256])

# %%
p = crop(image)

# %%
def rgb2lab(img):
    return color.rgb2lab(img)

def crop_image(img):
    """
    Random crop images to 256 * 256
    :param img:
    :return:
    """
    if img.size[0] < 256 or img.size[1] < 256:
        img = resize(img)

    img = crop(img)
    img = np.array(img)
    lab_image = rgb2lab(img)
    return torch.FloatTensor([lab_image[:,:,0]]), \
           torch.FloatTensor([lab_image[:,:,0], lab_image[:,:,1],lab_image[:,:,2]])

# %%
m,n = crop_image(image)
