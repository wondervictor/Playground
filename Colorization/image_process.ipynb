# %%
import torch
from torchvision import transforms
from PIL import Image

# %%
image_paths = ['test_images/201%s.jpg' % x for x in [2,3,4]]

image = Image.open(image_paths[0])

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=333x500 at 0x105D9D450>

# %%
random_crop = transforms.RandomCrop([256,256])

# %%
toTensor = transforms.ToTensor()
toPIL = transforms.ToPILImage()

# %%
image_tensor = random_crop(image)

# %%
image_tensor
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x105F7A850>

# %%
resize = transforms.Scale([100,300])

# %%
p = resize(image)

# %%
p
# Out:
# <PIL.Image.Image image mode=RGB size=100x300 at 0x105FB0CD0>

# %%
p.size
# Out:
# (100, 300)

# %%
resize = transforms.Scale(256)
p = resize(p)

# %%
p
# Out:
# <PIL.Image.Image image mode=RGB size=256x768 at 0x1039DB6D0>

# %%
p.size
# Out:
# (256, 768)
